# %%
import numpy as np
import pandas as pd
import pyflux as pf
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/sunspot.year.csv')
data.index = data['time'].values
plt.figure(figsize=(15, 5))
plt.plot(data.index, data['sunspot.year'])
plt.ylabel('Sunspots')
plt.title('Yearly Sunspot Data')
# Out:
# Text(0.5,1,'Yearly Sunspot Data')

# %%
model= pf.DAR(data=data, ar=9, integ=0, target='sunspot.year')

# %%
x = model.fit('MLE')
x.summary()
# Out:
# DAR(9, integrated=0)
# ======================================================= ==================================================
# Dependent Variable: sunspot.year                        Method: MLE
# Start Date: 1709                                        Log Likelihood: -1179.0946
# End Date: 1988                                          AIC: 2380.1892
# Number of observations: 280                             BIC: 2420.1719
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# Sigma^2 irregular                        0.3302
# Constant                                 59.8451    23.0012    2.6018   0.0093   (14.7627 | 104.9275)
# Sigma^2 AR(1)                            0.0053
# Sigma^2 AR(2)                            0.0
# Sigma^2 AR(3)                            0.0005
# Sigma^2 AR(4)                            0.0001
# Sigma^2 AR(5)                            0.0002
# Sigma^2 AR(6)                            0.0011
# Sigma^2 AR(7)                            0.0002
# Sigma^2 AR(8)                            0.0003
# Sigma^2 AR(9)                            0.032
# ==========================================================================================================

# %%
model.plot_fit(figsize=(30, 25))

# %%
model.plot_predict_is(h=50, figsize=(15, 10))
