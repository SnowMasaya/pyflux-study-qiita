# %%
import numpy as np
import pandas as pd
import pyflux as pf
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/MASS/drivers.csv')
data.index = data['time']

plt.figure(figsize=(15, 5))
plt.plot(data.index, data['drivers'])
plt.ylabel('Driver Deaths')
plt.title('Deaths of Car Drivers in Great Britain 1969-84')
plt.plot()
data_d = data['drivers']

# %%
data.loc[(data['time']>=1983.05), 'seat_belt'] = 1;
data.loc[(data['time']<1983.05), 'seat_belt'] = 0;
data.loc[(data['time']>=1974.00), 'oil_crisis'] = 1;
data.loc[(data['time']<1974.00), 'oil_crisis'] = 0;
plt.figure(figsize=(15, 5))
plt.plot(data.index, data['drivers'])
plt.ylabel('Driver Deaths')
plt.title('Deaths of Car Drivers in Great Britain 1969-84')
plt.plot()
# Out:
# []

# %%
model = pf.ARIMAX(data=data, formula='drivers~1+seat_belt+oil_crisis',
                 ar=1, ma=1, family=pf.Normal())
x = model.fit('MLE')
x.summary()
# Out:
# Normal ARIMAX(1,0,1)
# ======================================================= ==================================================
# Dependent Variable: drivers                             Method: MLE
# Start Date: 1969.08333333333                            Log Likelihood: -1297.4978
# End Date: 1984.91666666667                              AIC: 2606.9955
# Number of observations: 191                             BIC: 2626.5092
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# AR(1)                                    0.9171     0.076      12.0707  0.0      (0.7681 | 1.066)
# MA(1)                                    -0.0427    0.0862     -0.4947  0.6208   (-0.2117 | 0.1264)
# Beta 1                                   97.2921    146.7431   0.663    0.5073   (-190.3244 | 384.9086)
# Beta seat_belt                           19.8731    54.9479    0.3617   0.7176   (-87.8248 | 127.571)
# Beta oil_crisis                          46.3965    41.6955    1.1127   0.2658   (-35.3266 | 128.1197)
# Normal Scale                             215.7773
# ==========================================================================================================

# %%
model = pf.ARIMAX(data=data, formula='drivers~1+seat_belt',
                 ar=1, ma=1, family=pf.Normal())
x = model.fit('MLE')
x.summary()
# Out:
# Normal ARIMAX(1,0,1)
# ======================================================= ==================================================
# Dependent Variable: drivers                             Method: MLE
# Start Date: 1969.08333333333                            Log Likelihood: -1282.1762
# End Date: 1984.91666666667                              AIC: 2574.3524
# Number of observations: 191                             BIC: 2590.6138
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# AR(1)                                    0.5518     0.0885     6.2375   0.0      (0.3784 | 0.7252)
# MA(1)                                    0.1505     0.0978     1.5386   0.1239   (-0.0412 | 0.3422)
# Beta 1                                   768.9885   152.9668   5.0272   0.0      (469.1735 | 1068.8035)
# Beta seat_belt                           -168.5899  61.6122    -2.7363  0.0062   (-289.3498 | -47.83)
# Normal Scale                             199.1107
# ==========================================================================================================

# %%
model = pf.ARIMAX(data=data, formula='drivers~0+seat_belt',
                 ar=1, ma=1, family=pf.Normal())
x = model.fit('MLE')
x.summary()
# Out:
# Normal ARIMAX(1,0,1)
# ======================================================= ==================================================
# Dependent Variable: drivers                             Method: MLE
# Start Date: 1969.08333333333                            Log Likelihood: -1300.7146
# End Date: 1984.91666666667                              AIC: 2609.4292
# Number of observations: 191                             BIC: 2622.4383
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# AR(1)                                    0.9922     0.009      110.8392 0.0      (0.9746 | 1.0097)
# MA(1)                                    -0.0929    0.0843     -1.1022  0.2704   (-0.2581 | 0.0723)
# Beta seat_belt                           21.3736    43.3457    0.4931   0.6219   (-63.5839 | 106.3311)
# Normal Scale                             219.4404
# ==========================================================================================================

# %%
model = pf.ARIMAX(data=data, formula='drivers~1+oil_crisis',
                 ar=1, ma=1, family=pf.Normal())
x = model.fit('MLE')
x.summary()
# Out:
# Normal ARIMAX(1,0,1)
# ======================================================= ==================================================
# Dependent Variable: drivers                             Method: MLE
# Start Date: 1969.08333333333                            Log Likelihood: -1280.9354
# End Date: 1984.91666666667                              AIC: 2571.8708
# Number of observations: 191                             BIC: 2588.1322
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# AR(1)                                    0.5526     0.0854     6.4693   0.0      (0.3852 | 0.72)
# MA(1)                                    0.1461     0.0969     1.5077   0.1316   (-0.0438 | 0.3361)
# Beta 1                                   838.1382   161.2599   5.1974   0.0      (522.0688 | 1154.2077)
# Beta oil_crisis                          -131.4545  42.318     -3.1063  0.0019   (-214.3979 | -48.5112)
# Normal Scale                             197.8539
# ==========================================================================================================

# %%
model = pf.ARIMAX(data=data, formula='drivers~0+oil_crisis',
                 ar=1, ma=1, family=pf.Normal())
x = model.fit('MLE')
x.summary()
# Out:
# Normal ARIMAX(1,0,1)
# ======================================================= ==================================================
# Dependent Variable: drivers                             Method: MLE
# Start Date: 1969.08333333333                            Log Likelihood: -1300.5625
# End Date: 1984.91666666667                              AIC: 2609.1251
# Number of observations: 191                             BIC: 2622.1342
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# AR(1)                                    0.9853     0.014      70.4503  0.0      (0.9579 | 1.0127)
# MA(1)                                    -0.0875    0.0845     -1.0352  0.3006   (-0.2532 | 0.0782)
# Beta oil_crisis                          20.7012    28.1821    0.7345   0.4626   (-34.5359 | 75.9382)
# Normal Scale                             219.2673
# ==========================================================================================================

# %%
model = pf.ARIMAX(data=data, formula='drivers~0+seat_belt+oil_crisis',
                 ar=1, ma=1, family=pf.Normal())
x = model.fit('MLE')
x.summary()
# Out:
# Normal ARIMAX(1,0,1)
# ======================================================= ==================================================
# Dependent Variable: drivers                             Method: MLE
# Start Date: 1969.08333333333                            Log Likelihood: -1300.5332
# End Date: 1984.91666666667                              AIC: 2611.0665
# Number of observations: 191                             BIC: 2627.3278
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# AR(1)                                    0.9854     0.0141     70.0857  0.0      (0.9578 | 1.0129)
# MA(1)                                    -0.0877    0.0846     -1.0367  0.2999   (-0.2534 | 0.0781)
# Beta seat_belt                           8.2867     46.3221    0.1789   0.858    (-82.5046 | 99.078)
# Beta oil_crisis                          19.3518    30.0028    0.645    0.5189   (-39.4536 | 78.1572)
# Normal Scale                             219.2332
# ==========================================================================================================

# %%
model.plot_fit(figsize=(15, 10))

# %%
model = pf.ARIMAX(data=data, formula='drivers~seat_belt+oil_crisis',
                 ar=1, ma=1, family=pf.Normal())
x = model.fit('MLE')
x.summary()
# Out:
# Normal ARIMAX(1,0,1)
# ======================================================= ==================================================
# Dependent Variable: drivers                             Method: MLE
# Start Date: 1969.08333333333                            Log Likelihood: -1297.4978
# End Date: 1984.91666666667                              AIC: 2606.9955
# Number of observations: 191                             BIC: 2626.5092
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# AR(1)                                    0.9171     0.076      12.0707  0.0      (0.7681 | 1.066)
# MA(1)                                    -0.0427    0.0862     -0.4947  0.6208   (-0.2117 | 0.1264)
# Beta 1                                   97.2921    146.7431   0.663    0.5073   (-190.3244 | 384.9086)
# Beta seat_belt                           19.8731    54.9479    0.3617   0.7176   (-87.8248 | 127.571)
# Beta oil_crisis                          46.3965    41.6955    1.1127   0.2658   (-35.3266 | 128.1197)
# Normal Scale                             215.7773
# ==========================================================================================================

# %%
model.plot_fit(figsize=(15, 10))

# %%
model.plot_predict(h=10, oos_data=data.iloc[-12:], past_values=100, figsize=(15,5))
